# %% [markdown]
# # Artificial Intelligence - Fall 2022 - Laboratory 07
#
# ## _Constraint Satisfaction Problems (CCSPs)_

# %% [markdown]
# ## Introduction
#
# **Constraint Satisfaction Problems** are defined by:
# * a collection of discrete **variables**;
# * a **domain (range) of values** for each variable;
# * a set of **constraints** over variables.

# %% [markdown]
# ## From definitions to know-how

# %%
# Useful libraries:
from copy import copy, deepcopy
from itertools import combinations

# %% [markdown]
# Pythonic speaking:
#   - each variable will be represented by a string,
#
# ```python
#     vars_list = ['A', 'B', 'C']
# ```
#
#    - the set of domains will be a dictionary with one entry for each variable:
#      + the key will be the name of the variable,
#      + the value is given by the range values of that variable
#
# ```python
#     domains_dict = {'A': [1, 2, 3], 'B': [1, 5, 9], 'C': [-2, -1]}
# ```
#
#    - a constraint will be represented by a `tuple` consisting of:
#      + a `list` of variables involved in the constraint
#      + an anonymous function that returns `True` or `False`
#
# ```python
#     constraints = [(['A', 'B', 'C'], lambda a, b, c: a + b + c == 0)]
# ```
#
# The **solution** will be represented through a dictionary that indicates a value for each variable (e.g. `{'A': 1,'B': 1,'C': -2}`).
#
# The **cost** is given by the number of constraints ignored by the solution.

# %% [markdown]
# Math Problem

# %%
VarsA = ["A", "B", "C", "D", "E"]
DomainsA = {v: [i for i in range(10)] for v in VarsA}
ConstraintsA = [(list(p), lambda x,y: x != y) for p in combinations(VarsA, 2)] # all the values are different
ConstraintsA.append((["A","B"], lambda a,b: a + b == 10))
ConstraintsA.append((["B","D"], lambda b, d: b + d == 6))
ConstraintsA.append((["C"], lambda c: c < 5))
ConstraintsA.append((["A"], lambda a: a > 5))
ConstraintsA.append((["A","B","C","D","E"], lambda a, b, c, d, e: a + b + c + d + e == 30))
MathProblem = {"Vars": VarsA, "Domains": DomainsA, "Constraints": ConstraintsA}

# %% [markdown]
# Map-Coloring Problem

# %%
VarsC = ["France", "Germany", "Loux", "Belgium", "Netherlands"]
DomainsC = {v: ["blue", "red", "yellow", "green"] for v in VarsC}
ConstraintsC = []
for (a, b) in [("France", "Germany"), ("France", "Belgium"), ("France", "Loux"),
               ("Belgium", "Netherlands"), ("Belgium", "Loux"), ("Belgium", "Germany"),
               ("Loux", "Germany"), ("Netherlands", "Germany")]:
    ConstraintsC.append(([a, b], lambda a, b: a != b))
ColoringProblem = {"Vars": VarsC, "Domains": DomainsC, "Constraints": ConstraintsC}

# %% [markdown]
# ### Task 0
#
# Implement `get_constraints` function which receives a variable `var` and a list of constraints `constraints` and return only those constraints that entail the given variable.
#
# _Expected output:_
#
# ```
# Constraints = [(["A", "B"], lambda a,b: a<b), (["A"], lambda a: a<5)]
# get_constraints("B", Constraints)
# ==> [(["A", "B"], lambda a,b: a<b)]
# get_constraints("A", Constraints)
# ==> [(["A", "B"], lambda a,b: a<b), (["A"], lambda a: a<5)]
# ```

# %%
def get_constraints(var, constraints):
    # TODO
    sol=[(constrain) for constrain in constraints if var in constrain[0]]
    return sol

#print(ConstraintsC[0])

get_constraints('France', ConstraintsC) # => [(['France', 'Germany'], ...), (['France', 'Belgium'], ...), (['France', 'Loux'], ...)]
# Out:
# [(['France', 'Germany'], <function __main__.<lambda>(a, b)>),
#  (['France', 'Belgium'], <function __main__.<lambda>(a, b)>),
#  (['France', 'Loux'], <function __main__.<lambda>(a, b)>)]

# %% [markdown]
# ### Task 1
#
# Implement the `fixed_constraints` function which receives `solution` as a partial solution and a set of constraints `constraints`. The function returns only those constraints that can be evaluated (i.e. the variables involved are found in the partial solution).

# %%
def fixed_constraints(solution, constraints):
    #get the keys
    if solution!=None:
        keys=[key for key in solution.keys()]
        # create a list with all possible combinations with the keys
        constraints_keys=[list(element) for group_size in range(len(keys)+1) for element in combinations(keys,group_size)]
        # create a list with the constrains that have at least 1 of the keys
        keys_constrains=[]
        for key in keys:
            for constrain in get_constraints(key,constraints):
                if constrain not in keys_constrains:
                    keys_constrains.append(constrain)
        # return a list with the constrains that whose key is one of the possible keys
        result=[constrain for constrain in keys_constrains if constrain[0] in constraints_keys]
    else:
        result= []
    return result

print(fixed_constraints({"France": "blue", "Belgium": "green"}, ConstraintsC)) # => [(['France', 'Belgium'], ...)]
print(fixed_constraints({"A": "1", "C": "2"}, ConstraintsA)) # => [(['A', 'C'], ...), (['C'], ...), (['A'], ...)]
print(fixed_constraints({}, ConstraintsA))
# Out:
# [(['France', 'Belgium'], <function <lambda> at 0x000002CD2C235260>)]
# [(['A', 'C'], <function <listcomp>.<lambda> at 0x000002CD2C4B5A80>), (['A'], <function <lambda> at 0x000002CD2C4B5EE0>), (['C'], <function <lambda> at 0x000002CD2C4B5E40>)]
# []

# %% [markdown]
# ### Task 2
#
# Implement the `check_constraint` function which receives as a constraint the variable `constraint`, a partial solution `solution` and returns `True` if the solution respects the constraint and `False` otherwise.
#
# _**Hint:**_ to call a function knowing the list of its parameters use `f(*args)`, where `args` is the list of arguments.

# %%
def check_constraint(solution, constraint):
    # TODO
    keys=[key for key in solution.keys()]
    possible_key=[list(element) for group_size in range(len(keys)+1) for element in combinations(keys,group_size)]
    if constraint[0] in possible_key:
        values=[solution[key] for key in constraint[0]]
        return constraint[1](*values)
    else:
        return False

print(check_constraint({"France": "blue", "Belgium": "green"}, ConstraintsC[1])) # => True
print(check_constraint({"France": "blue", "Belgium": "blue"}, ConstraintsC[1])) # => False
print(check_constraint({"C": 10, "A": 10}, ConstraintsA[-2])) # => True
print(check_constraint({"C": 10, "A": 3}, ConstraintsA[-2])) # => False
# Out:
# True
# False
# True
# False

# %% [markdown]
# ### Task 3: PCSP algorithm
#
# Fill in what is missing in the PCSP algorithm.
#
# * `vars` - variables that remain to be checked
# * `domains` - the domains for the variables that remain to be verified, with the values that remain to be verified for each variable
# * `constrains` - the list of constraints
# * `acceptable_cost` - the cost for which the solution is considered satisfactory
# * `solution` - the partial solution, containing values for the variables checked so far
# * `cost` - the cost of unsatisfied constraints
#
# Function return value is `True` if a satisfactory complete solution has been found (see acceptable cost), and `False` otherwise.
#
# Two global variables are used:
#
# * `best_cost` - the best (smallest) cost so far in exploration, for a complete solution
# * `best_solution` - the solution corresponding to the best cost

# %%
def PCSP(vars, domains, constraints, acceptable_cost, solution, cost):
    global best_solution
    global best_cost
    print('--------------------------------------------------')
    print(best_cost)
    print(best_solution)
    if not vars:
        # If there are no more variables, we have reached a better solution
        print("New best: " + str(cost) + " - " + str(solution))
        # TODO: save the newly discovered solution
        best_solution=solution
        print('Salida por falta de vars')
        # TODO: if it is good enough, the function returns True
        if cost<=acceptable_cost:
            print('Salida por  coste aceptable')
            return True

    
    elif not domains[vars[0]]:
        # If there are no more values in the domains, the searching process ends
        print('Salida por falta de vals')
        return False
    elif cost == best_cost:
        # If we have already reached a cost identical with the one of the best solution, we will not go any further
        print('Salida por coste repetido')
        return False
    else:
        # TODO: Choose the first variable and the first value in the domains
        var = vars[0]
        val = domains[var].pop(0)
        print('Variable {} : Dominio {}'.format(var,domains[var]))

        # TODO: Build the new solution
        new_solution=deepcopy(solution)
        new_solution[var]=val
        print('Solucion parcial',new_solution)

        # TODO: We get the list of constraints that can be evaluated
        fixed=fixed_constraints(new_solution,constraints)
        #print('Fixed',fixed)
        # TODO: We compute the cost of the new partial solution (each constraint ignored = 1)
        True_constraints=[constrain for constrain in fixed if check_constraint(new_solution,constrain)]
        #print(True_constraints)
        new_cost = len(constraints)-len(True_constraints)
        print('nuevo coste ',new_cost)
        
        # We check if the new cost is lower than the best cost
        new_vars=deepcopy(vars)
        new_vars.pop(0)
        if new_cost < best_cost:
            # TODO:
            # If the new cost is lower than the best known, we solve for the rest of the variables
           
            # If the recursive call returns True, a good enough solution has been found, so we return True
            if PCSP(new_vars,domains,constraints,acceptable_cost,new_solution,new_cost):
                return True

            best_cost=new_cost
            

        
        # Check for the rest of the values
        # TODO:
        print('entra por abajo')
        PCSP(vars,domains,constraints,acceptable_cost,new_solution,cost)
       


        
    
# A wrapper that instantiates global variables
def run_pcsp(problem, acceptable_cost):
    global best_solution
    global best_cost

    [vars, domains, constraints] = [problem[e] for e in ["Vars", "Domains", "Constraints"]]
    
    best_solution = {}
    best_cost = len(constraints)

    if PCSP(deepcopy(vars), deepcopy(domains), constraints, acceptable_cost, {}, 0):
        print("Best found: " + str(best_cost) + " - " + str(best_solution))
    else:
        print("Acceptable solution not found; " + "Best found: " + str(best_cost) + " - " + str(best_solution))
        
# Run the algorithm
run_pcsp(MathProblem, 1)
#run_pcsp(ColoringProblem, 1)
# Out:
# --------------------------------------------------
# 15
# {}
# Variable A : Dominio [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 0}
# nuevo coste  15
# entra por abajo
# --------------------------------------------------
# 15
# {}
# Variable A : Dominio [2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 1}
# nuevo coste  15
# entra por abajo
# --------------------------------------------------
# 15
# {}
# Variable A : Dominio [3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 2}
# nuevo coste  15
# entra por abajo
# --------------------------------------------------
# 15
# {}
# Variable A : Dominio [4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 3}
# nuevo coste  15
# entra por abajo
# --------------------------------------------------
# 15
# {}
# Variable A : Dominio [5, 6, 7, 8, 9]
# Solucion parcial {'A': 4}
# nuevo coste  15
# entra por abajo
# --------------------------------------------------
# 15
# {}
# Variable A : Dominio [6, 7, 8, 9]
# Solucion parcial {'A': 5}
# nuevo coste  15
# entra por abajo
# --------------------------------------------------
# 15
# {}
# Variable A : Dominio [7, 8, 9]
# Solucion parcial {'A': 6}
# nuevo coste  14
# --------------------------------------------------
# 15
# {}
# Variable B : Dominio [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0}
# nuevo coste  13
# --------------------------------------------------
# 15
# {}
# Variable C : Dominio [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0}
# nuevo coste  11
# --------------------------------------------------
# 15
# {}
# Variable D : Dominio [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0}
# nuevo coste  10
# --------------------------------------------------
# 15
# {}
# Variable E : Dominio [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 0}
# nuevo coste  9
# --------------------------------------------------
# 15
# {}
# New best: 9 - {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 0}
# Salida por falta de vars
# entra por abajo
# --------------------------------------------------
# 9
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 0}
# Variable E : Dominio [2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# nuevo coste  6
# --------------------------------------------------
# 9
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 0}
# New best: 6 - {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vars
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio [3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 2}
# nuevo coste  6
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio [4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 3}
# nuevo coste  6
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio [5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 4}
# nuevo coste  6
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio [6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 5}
# nuevo coste  6
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio [7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 6}
# nuevo coste  7
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio [8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 7}
# nuevo coste  6
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio [9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 8}
# nuevo coste  6
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable E : Dominio []
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 9}
# nuevo coste  6
# entra por abajo
# --------------------------------------------------
# 6
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 1}
# nuevo coste  8
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 2}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 3}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 4}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 5}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 6}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 7}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio [9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 8}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable D : Dominio []
# Solucion parcial {'A': 6, 'B': 0, 'C': 0, 'D': 9}
# nuevo coste  8
# entra por abajo
# --------------------------------------------------
# 8
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# entra por abajo
# --------------------------------------------------
# 11
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 1}
# nuevo coste  10
# --------------------------------------------------
# 11
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 2}
# nuevo coste  10
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 3}
# nuevo coste  10
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 4}
# nuevo coste  10
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 5}
# nuevo coste  11
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [7, 8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 6}
# nuevo coste  12
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [8, 9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 7}
# nuevo coste  11
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio [9]
# Solucion parcial {'A': 6, 'B': 0, 'C': 8}
# nuevo coste  11
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable C : Dominio []
# Solucion parcial {'A': 6, 'B': 0, 'C': 9}
# nuevo coste  11
# entra por abajo
# --------------------------------------------------
# 10
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# entra por abajo
# --------------------------------------------------
# 13
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [2, 3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 1}
# nuevo coste  13
# entra por abajo
# --------------------------------------------------
# 13
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [3, 4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 2}
# nuevo coste  13
# entra por abajo
# --------------------------------------------------
# 13
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [4, 5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 3}
# nuevo coste  13
# entra por abajo
# --------------------------------------------------
# 13
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [5, 6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 4}
# nuevo coste  12
# --------------------------------------------------
# 13
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# entra por abajo
# --------------------------------------------------
# 12
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [6, 7, 8, 9]
# Solucion parcial {'A': 6, 'B': 5}
# nuevo coste  13
# entra por abajo
# --------------------------------------------------
# 12
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [7, 8, 9]
# Solucion parcial {'A': 6, 'B': 6}
# nuevo coste  14
# entra por abajo
# --------------------------------------------------
# 12
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [8, 9]
# Solucion parcial {'A': 6, 'B': 7}
# nuevo coste  13
# entra por abajo
# --------------------------------------------------
# 12
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio [9]
# Solucion parcial {'A': 6, 'B': 8}
# nuevo coste  13
# entra por abajo
# --------------------------------------------------
# 12
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable B : Dominio []
# Solucion parcial {'A': 6, 'B': 9}
# nuevo coste  13
# entra por abajo
# --------------------------------------------------
# 12
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# entra por abajo
# --------------------------------------------------
# 14
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable A : Dominio [8, 9]
# Solucion parcial {'A': 7}
# nuevo coste  14
# entra por abajo
# --------------------------------------------------
# 14
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable A : Dominio [9]
# Solucion parcial {'A': 8}
# nuevo coste  14
# entra por abajo
# --------------------------------------------------
# 14
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Variable A : Dominio []
# Solucion parcial {'A': 9}
# nuevo coste  14
# entra por abajo
# --------------------------------------------------
# 14
# {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# Salida por falta de vals
# Acceptable solution not found; Best found: 14 - {'A': 6, 'B': 0, 'C': 0, 'D': 0, 'E': 1}

# %% [markdown]
# Expected output for numbers:
#
# ```
# New best: 14 - {'A': 0, 'B': 0, 'C': 0, 'D': 0, 'E': 0}
# New best: 10 - {'A': 0, 'B': 0, 'C': 0, 'D': 0, 'E': 1}
# New best: 8 - {'A': 0, 'B': 0, 'C': 0, 'D': 1, 'E': 1}
# New best: 7 - {'A': 0, 'B': 0, 'C': 0, 'D': 1, 'E': 2}
# New best: 6 - {'A': 0, 'B': 0, 'C': 0, 'D': 6, 'E': 1}
# New best: 5 - {'A': 0, 'B': 0, 'C': 1, 'D': 2, 'E': 3}
# New best: 4 - {'A': 0, 'B': 0, 'C': 1, 'D': 6, 'E': 2}
# New best: 3 - {'A': 0, 'B': 1, 'C': 2, 'D': 5, 'E': 3}
# New best: 2 - {'A': 2, 'B': 8, 'C': 4, 'D': 7, 'E': 9}
# New best: 1 - {'A': 6, 'B': 4, 'C': 0, 'D': 2, 'E': 1}
# Best found: 1 - {'A': 6, 'B': 4, 'C': 0, 'D': 2, 'E': 1}
# ```
#
# Expected output for country colors:
#
# ```
# New best:  8  -  {'Loux': 'blue', 'Belgium': 'blue', 'Netherlands': 'blue', 'Germany': 'blue', 'France': 'blue'}
# New best:  6  -  {'Loux': 'blue', 'Belgium': 'blue', 'Netherlands': 'red', 'Germany': 'blue', 'France': 'blue'}
# New best:  4  -  {'Loux': 'blue', 'Belgium': 'red', 'Netherlands': 'blue', 'Germany': 'blue', 'France': 'blue'}
# New best:  3  -  {'Loux': 'blue', 'Belgium': 'red', 'Netherlands': 'yellow', 'Germany': 'blue', 'France': 'blue'}
# New best:  2  -  {'Loux': 'red', 'Belgium': 'red', 'Netherlands': 'yellow', 'Germany': 'blue', 'France': 'blue'}
# New best:  1  -  {'Loux': 'red', 'Belgium': 'yellow', 'Netherlands': 'red', 'Germany': 'blue', 'France': 'blue'}
# Best found: 1  -  {'Loux': 'red', 'Belgium': 'yellow', 'Netherlands': 'red', 'Germany': 'blue', 'France': 'blue'}
# ```
